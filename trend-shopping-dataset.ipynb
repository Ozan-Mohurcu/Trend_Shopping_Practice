# %% [markdown]
# # **Ozan Möhürcü**
# <p style="font-size: 1.5rem; font-weight: bold;">Data Analyst | Data Scientist </p>
#
# Hello! I am Ozan, a data analyst who is open to learning and who improves myself in analytical thinking and producing data-driven solutions. I have successfully completed my analyst training and am currently focusing on data science and increasing my competencies in this field.
#
# 📊 What Do I Know?
#
# I can extract meaningful results from data by working with Python, SQL and data visualization tools.
# I am constantly improving myself in statistical analysis and reporting.
# I aim to solve problems and support decision processes with the insights I obtain.
#
# 📚 What Am I Doing Right Now?
# In my data science training, I am gaining knowledge on topics such as machine learning and big data analytics. In addition, I am looking for opportunities to put my theoretical knowledge into practice by gaining experience in real-world projects.
#
# 🎯 My Goal:
# To contribute to the growth goals of companies by using my talents in data analysis and data science in a way that will create value in the business world. I am here to learn new information and to constantly improve by sharing my experiences.
#
# If you would like to discuss projects, collaborate or share experiences, I would be happy to connect!
#
#
# <div style="text-align: left; font-family: Arial, sans-serif; margin-top: 20px;">
#     <a href="https://www.linkedin.com/in/ozanmhrc/" style="text-decoration: none; color: #fff; margin-right: 10px;">
#         <span style="background-color: #0077B5; padding: 8px 20px; border-radius: 5px; font-size: 14px; display: inline-block; width: 120px; text-align: center;">LinkedIn</span>
#     </a>
#     <a href="https://github.com/Ozan-Mohurcu" style="text-decoration: none; color: #fff; margin-right: 10px;">
#         <span style="background-color: #333; padding: 8px 20px; border-radius: 5px; font-size: 14px; display: inline-block; width: 120px; text-align: center;">GitHub</span>
#     </a>
#     <a href="https://www.kaggle.com/ozanmhrc" style="text-decoration: none; color: #fff; margin-right: 10px;">
#         <span style="background-color: #20BEFF; padding: 8px 20px; border-radius: 5px; font-size: 14px; display: inline-block; width: 120px; text-align: center;">Kaggle</span>
#     </a>
# </div>

# %% [markdown]
# ## 📊 Dataset Overview
#
# - Customer ID: A unique identification number that identifies the customer.
# - Age: The customer's age.
# - Gender: The customer's gender (e.g., Female, Male, Non-binary).
# - Item Purchased: The name of the product the customer purchased.
# - Category: The category the product belongs to (e.g., Clothing, Electronics, Home Appliances).
# - Purchase Amount (USD): The total amount of the customer's purchase (in USD).
# - Location: The geographic region or city where the customer is located.
# - Size: The size of the purchased item (e.g., S, M, L, XL).
# - Color: The color of the purchased item.
# - Season: The season when the purchase occurred (e.g., Summer, Winter, Spring, Fall).
# - Review Rating: The rating given by the customer about the product (usually on a scale of 1-5).
# - Subscription Status: Whether the customer is a subscriber.
# - Payment Method: The payment method the customer uses (e.g., Credit Card, PayPal, Bank Transfer).
# - Shipping Type: How the product is shipped (e.g., Standard Shipping, Express Shipping).
# - Discount Applied: The discount rate applied at the time of purchase.
# - Promo Code Used: The promotional code the customer used during the purchase.
# - Previous Purchases: A list of the customer's past purchases.
# - Preferred Payment Method: The customer's preferred payment method for future purchases.
# - Frequency of Purchases: How often the customer makes purchases (e.g., Once a Week, Once a Month).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
df = pd.read_csv("shopping_trends.csv")
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df1= df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3900 non-null   int64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3900 non-null   int64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3900 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
df.describe(exclude = 'object').style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_6d2df_row0_col0, #T_6d2df_row0_col1, #T_6d2df_row0_col2, #T_6d2df_row0_col3, #T_6d2df_row0_col4, #T_6d2df_row7_col0 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_6d2df_row1_col0, #T_6d2df_row5_col0 {
#   background-color: #8c95c6;
#   color: #f1f1f1;
# }
# #T_6d2df_row1_col1, #T_6d2df_row1_col4, #T_6d2df_row4_col1, #T_6d2df_row4_col2, #T_6d2df_row5_col1, #T_6d2df_row5_col4 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_6d2df_row1_col2, #T_6d2df_row5_col2, #T_6d2df_row6_col1, #T_6d2df_row6_col4 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_6d2df_row1_col3, #T_6d2df_row2_col1, #T_6d2df_row2_col2, #T_6d2df_row2_col3, #T_6d2df_row2_col4, #T_6d2df_row3_col0, #T_6d2df_row3_col1, #T_6d2df_row3_col2, #T_6d2df_row3_col3, #T_6d2df_row3_col4, #T_6d2df_row4_col3, #T_6d2df_row4_col4, #T_6d2df_row5_col3, #T_6d2df_row6_col3, #T_6d2df_row7_col3 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_6d2df_row2_col0 {
# ...

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)  
plt.hist(df['Age'], bins=10, color='skyblue', edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)  
age_counts = df['Age'].value_counts()

explode = [0.1 if i in age_counts.nlargest(2).index else 0 for i in age_counts.index]
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%', startangle=90, explode=explode, shadow=True)
plt.title('Age Distribution Pie Chart')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
gender_counts = df['Gender'].value_counts()

fig, axes = plt.subplots(1, 2, figsize=(10, 4))

sns.countplot(data=df, x='Gender', palette='Blues', ax=axes[0])
axes[0].set_title('Gender Count')
axes[0].set_xlabel('Gender')
axes[0].set_ylabel('Count')

explode = [0.1 if i in gender_counts.nlargest(2).index else 0 for i in gender_counts.index]
axes[1].pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', explode=explode, shadow=True, colors=sns.color_palette("Blues", len(gender_counts)))
axes[1].set_title('Gender Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.countplot(data=df, x='Category', palette='Blues', ax=axes[0])
axes[0].set_title('Category Count')
axes[0].set_xlabel('Category')
axes[0].set_ylabel('Count')

category_counts = df['Category'].value_counts()
explode = [0.1 if i in category_counts.nlargest(2).index else 0 for i in category_counts.index]
axes[1].pie(category_counts, labels=category_counts.index, autopct='%1.2f%%', explode=explode, shadow=True, colors=sns.color_palette("Blues", len(category_counts)))
axes[1].set_title('Category Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
df['Purchase Amount (USD)'].describe()
# Out:
# count    3900.000000
# mean       59.764359
# std        23.685392
# min        20.000000
# 25%        39.000000
# 50%        60.000000
# 75%        81.000000
# max       100.000000
# Name: Purchase Amount (USD), dtype: float64

# %%
fig, axes = plt.subplots(1,2, figsize = (12,4))

sns.histplot(data = df, x = "Purchase Amount (USD)", ax = axes[0], kde = True)
sns.boxplot(data= df, x = "Purchase Amount (USD)", ax = axes[1])
plt.show()

# %% [markdown]
# ---

# %%
plt.figure(figsize = (8,6))

ax = sns.countplot(x = df['Payment Method'],palette='Blues')

for i in ax.containers:
    ax.bar_label(i)
    
plt.title('Count Payment Method')
plt.show()

# %% [markdown]
# ---

# %%
plt.figure(figsize = (8,6))
sns.countplot(data = df, x = 'Size', palette='Blues')
plt.title("Size Distribution")
plt.show()

# %% [markdown]
# ---

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

sns.countplot(data=df, x='Season', palette='Blues', ax=axes[0])
axes[0].set_title('Season Count')
axes[0].set_xlabel('Season')
axes[0].set_ylabel('Count')

season_counts = df['Season'].value_counts()
explode = [0.1 if i in season_counts.nlargest(2).index else 0 for i in season_counts.index]
axes[1].pie(season_counts, labels=season_counts.index, autopct='%1.2f%%', explode=explode, shadow=True, colors=sns.color_palette("Blues", len(season_counts)))
axes[1].set_title("Sales Rates by Season")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.scatterplot(data = df, x = 'Purchase Amount (USD)', y = 'Review Rating')
plt.show()

# %%
import folium
from geopy.geocoders import Nominatim

data = {
    "Location": ["Montana", "California", "Idaho", "Illinois", "Alabama", 
                 "Minnesota", "Nebraska", "New York", "Nevada", "Maryland"],
    "Score": [96, 95, 93, 92, 89, 88, 87, 87, 87, 86]
}

geolocator = Nominatim(user_agent="state_location_map")

map_center = [37.0902, -95.7129]  
m = folium.Map(location=map_center, zoom_start=5)

for i, row in enumerate(data['Location']):
    try:
        location = geolocator.geocode(row + ", USA", timeout=10)  
        if location:
            folium.Marker(
                location=[location.latitude, location.longitude],
                popup=f"{row}: {data['Score'][i]}",
                icon=folium.Icon(color='blue', icon='info-sign')
            ).add_to(m)
    except Exception as e:
        print(f"Error with {row}: {e}")

m.save("state_location_map.html")
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### **Analysis Results** 📊
#
# #### **Customer Demographics** 👥
# - Average age of customers: **44.07** 🧑‍🦳
# - Most are between **31-57**. 🎂
# - **Gender distribution**: Male customers are more than female customers. 👨‍🦱👩
#
# #### **Purchasing Behaviors** 🛍️
# - **Average purchase amount**: **59.76 USD** 💵
# - Most customers shop between **39-81 USD**. 💳
# - Most purchased product categories:
# - **Clothing** (Clothing) 👗👚
# - **Footwear** (Shoes) 👠👟
# - **Average review score**: **3.75** ⭐ (Customers are satisfied with the products)
#
# #### **Subscription and Payment Methods** 🏷️💳
# - Over 70% of customers have **subscription service**. 📝
# - **Most preferred payment method**: **Credit Card** 💳.
#
# #### **Seasonal Trends** 🌸🍂
# - **Busiest purchasing period**: **Spring** 🌷.
# - Increasing campaigns and discounts during this period may create opportunities.
#
# #### **Effect of Discounts and Promotions** 💸
# - **Discounted purchases** increase the average purchase amount. 🔥
# - **Using a promotional code** increases the frequency of customers' purchases. 🏷️
#
# ---
#
# ### **Recommendations** 💡
#
# #### **Targeted Marketing Strategies** 🎯
# - Special campaigns can be organized for customers between the ages of **31-57**. 🎉
# - Special discounts and campaigns can be organized for female customers. 👩‍🦰👚
#
# #### **Focus on Product Categories** 👗👟
# - The variety of products in the "Clothing" and "Footwear" categories can be increased and products in these categories can be highlighted.
#
# #### **Improving Subscription Service** 🔄
# - Special advantages can be offered to customers with subscription service. 🎁
# - Incentive campaigns can be organized for customers without subscription service.
#
# #### **Seasonal Campaigns** 🌸🎉
# - Due to the increase in purchases in the spring months, special campaigns and discounts can be organized during this period. 🌼
#
# #### **Optimization of Discounts and Promotions** 🛒
# - Considering that discounts increase the amount of purchases, more frequent and strategic discounts can be organized. 📉
#
# #### **Increasing Customer Satisfaction** 🌟
# - Product and service quality can be improved by taking customer feedback into account to increase review scores. 📝
# - Services such as fast shipping and easy return policies can be offered. 🚚🔄
#
# #### **Data-Based Decision Making** 📈
# - By conducting in-depth analysis, purchasing behaviors can be better understood and strategies can be shaped accordingly. 💡

# %% [markdown]
# ### **Analiz Sonuçları** 📊
#
# #### **Müşteri Demografisi** 👥
# - Müşterilerin yaş ortalaması: **44.07** 🧑‍🦳
# - Çoğunluğu **31-57 yaş** aralığında yer almaktadır. 🎂
# - **Cinsiyet dağılımı**: Erkek müşteriler, kadın müşterilere göre daha fazladır. 👨‍🦱👩
#
# #### **Satın Alma Davranışları** 🛍️
# - **Ortalama satın alma miktarı**: **59.76 USD** 💵
# - Çoğu müşteri **39-81 USD** aralığında alışveriş yapmaktadır. 💳
# - En çok satın alınan ürün kategorileri:
#   - **Clothing** (Giyim) 👗👚
#   - **Footwear** (Ayakkabı) 👠👟
# - **Ortalama inceleme puanı**: **3.75** ⭐ (Müşteriler ürünlerden memnun)
#
# #### **Abonelik ve Ödeme Yöntemleri** 🏷️💳
# - %70'in üzerinde müşteri **abonelik hizmetine** sahiptir. 📝
# - **En çok tercih edilen ödeme yöntemi**: **Kredi Kartı** 💳.
#
# #### **Mevsimsel Trendler** 🌸🍂
# - **En yoğun satın alma dönemi**: **İlkbahar** (Spring) 🌷.
#   - Bu dönemde kampanyaların ve indirimlerin artırılması fırsat yaratabilir.
#
# #### **İndirim ve Promosyonların Etkisi** 💸
# - **İndirim uygulanan satın alımlar**, ortalama satın alma miktarını artırmaktadır. 🔥
# - **Promosyon kodu kullanımı**, müşterilerin satın alma sıklığını artırmaktadır. 🏷️
#
# ---
#
# ### **Öneriler** 💡
#
# #### **Hedefli Pazarlama Stratejileri** 🎯
# - **31-57 yaş** aralığındaki müşterilere yönelik özel kampanyalar düzenlenebilir. 🎉
# - Kadın müşterilere yönelik özel indirimler ve kampanyalar düzenlenebilir. 👩‍🦰👚
#
# #### **Ürün Kategorilerine Odaklanma** 👗👟
# - "Clothing" ve "Footwear" kategorilerindeki ürünlerin çeşitliliği artırılabilir ve bu kategorilerdeki ürünler ön plana çıkarılabilir.
#
# #### **Abonelik Hizmetinin Geliştirilmesi** 🔄
# - Abonelik hizmetine sahip müşterilere özel avantajlar sunulabilir. 🎁
# - Abonelik hizmetine sahip olmayan müşterilere yönelik teşvik kampanyaları düzenlenebilir.
#
# #### **Mevsimsel Kampanyalar** 🌸🎉
# - İlkbahar aylarında satın almaların artması nedeniyle bu dönemde özel kampanyalar ve indirimler düzenlenebilir. 🌼
#
# #### **İndirim ve Promosyonların Optimizasyonu** 🛒
# - İndirimlerin satın alma miktarını artırdığı göz önünde bulundurularak, daha sık ve stratejik indirimler düzenlenebilir. 📉
#
# #### **Müşteri Memnuniyetini Artırma** 🌟
# - İnceleme puanlarının artırılması için müşteri geri bildirimleri dikkate alınarak ürün ve hizmet kalitesi iyileştirilebilir. 📝
# - Hızlı kargo ve kolay iade politikaları gibi hizmetler sunulabilir. 🚚🔄
#
# #### **Veriye Dayalı Karar Alma** 📈
# - Derinlemesine analizler yapılarak satın alma davranışları daha iyi anlaşılabilir ve stratejiler buna göre şekillendirilebilir. 💡
